# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\rinsu\\OneDrive\Desktop\\SCALER\\New folder\\paintings\\subject.csv")

# %%
df.head()
# Out:
#    work_id     subject
# 0   160228  Still-Life
# 1   160236  Still-Life
# 2   160244  Still-Life
# 3   160252  Still-Life
# 4   160260  Still-Life

# %%
df.dtypes
# Out:
# work_id     int64
# subject    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# work_id    0
# subject    0
# dtype: int64

# %%
y = []

for i in range(len(df)):
    x = tuple(df.iloc[i])
    y.append(x)
y
# Out:
# [(160228, 'Still-Life'),
#  (160236, 'Still-Life'),
#  (160244, 'Still-Life'),
#  (160252, 'Still-Life'),
#  (160260, 'Still-Life'),
#  (160268, 'Still-Life'),
#  (125752, 'Horses'),
#  (23448, 'Horses'),
#  (125763, 'Horses'),
#  (24532, 'Marine Art/Maritime'),
#  (124470, 'Marine Art/Maritime'),
#  (124479, 'Marine Art/Maritime'),
#  (124488, 'Marine Art/Maritime'),
#  (124497, 'Marine Art/Maritime'),
#  (124506, 'Marine Art/Maritime'),
#  (124515, 'Marine Art/Maritime'),
#  (124524, 'Marine Art/Maritime'),
#  (124533, 'Marine Art/Maritime'),
#  (124542, 'Marine Art/Maritime'),
#  (124551, 'Marine Art/Maritime'),
#  (124560, 'Marine Art/Maritime'),
#  (124569, 'Marine Art/Maritime'),
#  (124578, 'Marine Art/Maritime'),
#  (124587, 'Marine Art/Maritime'),
#  (135881, 'Portraits'),
#  (135892, 'Portraits'),
#  (135903, 'Portraits'),
#  (135914, 'Portraits'),
#  (135925, 'Portraits'),
#  (135936, 'Portraits'),
#  (135947, 'Portraits'),
#  (135958, 'Portraits'),
# ...

# %%
file = open('subject.txt','w')
for tuple in y:
    file.write(str(tuple)+','+'\n')
file.close()
